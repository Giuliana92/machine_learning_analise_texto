# %% [markdown]
#  <img src=ironhack.jpg alt="drawing" width="200"/>

# %% [markdown]
# # Projeto final do curso de Data Analytics PT-JUL-2020, Ironhack São Paulo

# %% [markdown]
# ## Tema abordado: Técnicas de Machine Learning para Análise de Texto

# %% [markdown]
# **IRONHACKERS: GIULIANA VICENTE E WAGNER FRANÇA**

# %% [markdown]
# O presente projeto tem por objetivo analisar os textos produzidos por onze figuras políticas através da extração de dados de suas contas do Twitter. Para sua realização foi aplicado NLTK e SKLEARN com objetivo de treinar modelos de Regressão Logística que identificassem à qual figura política pertencem ou podem pertencer determinadas frases.

# %%
import nltk 
from nltk.stem import RSLPStemmer
import re
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression as lr
from sklearn.model_selection import train_test_split

# %% [markdown]
# #  Importando csv

# %% [markdown]
# **Figuras Políticas escolhidas:  Dilma Rousseff, Manuela d'Ávila, Marina Silva, Damares Alves, Bruno Covas, Guilherme Boulos, Jair Bolsonaro, Lula, Celso Russomanno, João Dória e Marcelo Crivella.**

# %%
tweet_covas = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/covas_2020.csv')
tweet_boulos = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/boulos_2020.csv').sample(2100)
tweet_russomanno = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/celsorussomanno_2020.csv')
tweet_doria = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/doria_2020.csv').sample(2100)
tweet_crivella = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/crivella_2020.csv')
tweet_bolsonaro = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/jairbolsonaro_2020.csv').sample(2100)
tweet_lula = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/lula_2020.csv').sample(2100)
tweet_damares = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/damares_2020.csv').sample(2100)
tweet_dilma = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/dilmabr_2020.csv')
tweet_manuela = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/ManuelaDavila_2020.csv').sample(2100)
tweet_marina = pd.read_csv ('C:/Users/giuli/Desktop/Dados_Twitter/MarinaSilva_2020.csv')

# %%
covas = tweet_covas [["tweet" , "name"]]
boulos = tweet_boulos [["tweet" , "name"]]
russomanno = tweet_russomanno [["tweet" , "name"]]
doria = tweet_doria [["tweet" , "name"]]
bolsonaro = tweet_bolsonaro [["tweet" , "name"]]
crivella = tweet_crivella [["tweet" , "name"]]
lula = tweet_lula [["tweet" , "name"]]
damares = tweet_damares [["tweet" , "name"]]
dilma = tweet_dilma [["tweet" , "name"]]
manuela = tweet_manuela [["tweet" , "name"]]
marina = tweet_marina [["tweet" , "name"]]

# %% [markdown]
# ## Base de dados para treino e teste

# %%
tweets_treino = pd.concat([covas, boulos, russomanno, doria, bolsonaro, crivella, lula, dilma, damares, manuela, marina],ignore_index = True)
tweets_teste = pd.concat([covas.sample(100), boulos.sample(100), russomanno.sample(100), doria.sample(100), bolsonaro.sample(100), crivella.sample(100), lula.sample(100), dilma.sample(100), damares.sample(100), manuela.sample(100), marina.sample(100)],ignore_index = True)

# %% [markdown]
# ## Stop Words

# %%
#tweets_treino['Stemmer'] = tweets_treino['tweet']

# %%
stop_words = nltk.corpus.stopwords.words('portuguese')

# %%
def steming(df):
    

    for x in range(len(df['tweet'])):
            phrase = []
            tt = re.sub('[^\w\s]|\d','',df.iloc[x][0]).lower().split()
            for y in tt:
                if y not in stop_words:
                    phrase.append(RSLPStemmer().stem(y))
            joinha = ' '.join(map(str, phrase))
            df['tweet'].iloc[x] = joinha
            
    return df

# %% [markdown]
# ## Aplicando Stemmer no treino

# %%
steming(tweets_treino)
# Out:
#                                                    tweet          name
# 0                                     igor_k dia sáb top   Bruno Covas
# 1      obrig paul milhã vot ench esperanç hor transfo...   Bruno Covas
# 2       cole brun cov todosporsaopaul httpstcosldrgajzjn   Bruno Covas
# 3                                    vot todosporsaopaul   Bruno Covas
# 4      dur tod campanh preocup verdad palavr bonit pr...   Bruno Covas
# ...                                                  ...           ...
# 15894  irrespons negacion climá agrav aind situ tom m...  Marina Silva
# 15895  neglig primeiroministr australi scott morrison...  Marina Silva
# 15896  apavor ver terr incêndi florest austrál mat pe...  Marina Silva
# 15897  estratég trump ataqu busc reaviv nacion conser...  Marina Silva
# 15898  ataqu govern norteameric bagd mat gener irani ...  Marina Silva
#
# [15899 rows x 2 columns]

# %%
def digite(frase):    
    
    z = pd.DataFrame([frase], columns=['tweet'])
    steming(z)
    w = cv.transform (z['tweet']).todense()
    g = pd.DataFrame(w,columns=cv.get_feature_names())
    wg = pd.DataFrame(model.predict_proba(g),columns = model.classes_).T
    #results = pd.DataFrame(model.predict_proba(teste1),columns = model.classes_)
    return wg.reset_index().rename(columns={0: "Probabilidade", "index": "Figura_Politica"})
    #return results[model.predict(teste1)[0]]

# %% [markdown]
# ## Aplicando a vetorização dos dados de texto e transformando-os em uma matriz de frequência

# %%
cv = CountVectorizer()
cv.fit(tweets_treino['tweet'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
matrix = cv.transform (tweets_treino['tweet']).todense()

# %%
cv.get_feature_names()
# Out:
# ['_anapastor_',
#  '_clacs',
#  '_cojub',
#  '_heloisa_helen',
#  '_leolima',
#  '_lucasfigueired',
#  '_ludaltr',
#  '_makavelijon',
#  '_nossieg',
#  '_ofic',
#  '_pablitoagui',
#  '_pinh',
#  '_prez',
#  '_uivan',
#  '_umesp',
#  '_zevagn',
#  'a_estupid',
#  'aaaalô',
#  'aaaeguarujásp',
#  'aamic',
#  'ab',
#  'aba',
#  'abaix',
#  'abaixoacens',
#  'abaixoassin',
#  'abal',
#  'aban',
#  'abandon',
#  'abastec',
#  'abastecimentosegurospgovbr',
#  'abasteç',
#  'abat',
#  'abbey',
#  'abc',
#  'abdi_digit',
#  'abdic',
#  'abduch',
#  'abduç',
#  'abelh',
#  'abenf',
#  'abenço',
#  'abençõ',
#  'aberr',
#  'abert',
#  'abeshinz',
#  'abidjã',
#  'abin',
#  'abism',
#  'abjet',
#  'abneg',
#  'abnerdangel',
#  'abol',
#  'abomin',
#  'abon',
#  'abord',
#  'abort',
#  'about',
#  'abp',
#  'abr',
#  'abra',
#  'abrac',
#  'abraceomaraj',
#  'abraceomarajó',
#  'abraceori',
#  'abracosolidari',
#  'abracovirt',
#  'abracovirtualesefossevoceorg',
#  'abrah',
#  'abrahamweint',
#  'abrahim',
#  'abrang',
#  'abraz',
#  'abraç',
#  'abraçovirt',
#  'abraçál',
#  'abres',
#  'abrevi',
#  'abrig',
#  'abril',
#  'abrilazul',
#  'abrilhant',
#  'abrilindígen',
#  'abrupt',
#  'absolut',
#  'absolv',
#  'absorv',
#  'abstenç',
#  'abstin',
#  'abstrat',
#  'absurd',
#  'abu',
#  'abuel',
#  'abuelasdifusion',
#  'abuj',
#  'abunã',
#  'abus',
#  'abusonãoébrinc',
#  'ac',
#  'acab',
#  'acaboubolsonar',
#  'academ',
#  'acadepol',
#  'acadêm',
#  'acajutib',
#  'acalent',
#  'acalm',
#  'acamp',
#  'acanh',
#  'acaodacidadan',
#  'acare',
#  'acarlaosant',
#  'acarolamar',
#  'acarret',
#  'acas',
#  'acat',
#  'acc',
#  'acceitec',
#  'accioly',
#  'aceit',
#  'aceler',
#  'acen',
#  'acend',
#  'acepç',
#  'acert',
#  'acertad',
#  'acerv',
#  'aces',
#  'acess',
#  'acessibil',
#  'acessóri',
#  'ach',
#  'achat',
#  'achincalh',
#  'aci',
#  'acid',
#  'acident',
#  'acim',
#  'aciolisc',
#  'acion',
#  'acm',
#  'acobert',
#  'acolh',
#  'acolhaav',
#  'acolhedorassetembroamarel',
#  'acolhinent',
#  'acomet',
#  'acomoanh',
#  'acompanh',
#  'aconselh',
#  'acontec',
#  'aconteç',
#  'acopi',
#  'acopl',
#  'acord',
#  'acostum',
#  'acr',
#  'acre',
#  'acredit',
#  'acreditasãopaul',
#  'acrescent',
#  'acrescentes',
#  'acrislil',
#  'acrpol',
#  'acrésc',
#  'acríl',
#  'act',
#  'activat',
#  'acu',
#  'acumplic',
#  'acumul',
#  'acus',
#  'acusando',
#  'acusál',
#  'acéfal',
#  'acórd',
#  'acõ',
#  'acúmul',
#  'ad',
#  'ada',
#  'adacolau',
#  'adadlel',
#  'adalt',
#  'adapt',
#  'adel',
#  'adelisell',
#  'adelsonantoni',
#  'adem',
#  'ademirduarteb',
#  'adept',
#  'adequ',
#  'adequad',
#  'ader',
#  'ades',
#  'adeu',
#  'adgm',
#  'adi',
#  'adiaen',
#  'adiant',
#  'adic',
#  'adicion',
#  'adilsonaraj',
#  'adilsonctb',
#  'adin',
#  'adit',
#  'adiv',
#  'adivinh',
#  'adjunt',
#  'adm',
#  'administr',
#  'admir',
#  'admiss',
#  'admissibil',
#  'admit',
#  'adoaçãorespons',
#  'adoec',
#  'adolesc',
#  'adolescentesdev',
#  'adolf',
#  'ador',
#  'adormec',
#  'adot',
#  'adotál',
#  'adoç',
#  'adpf',
#  'adqu',
#  'adqueved',
#  'adquir',
#  'adri',
#  'adriana_accors',
#  'adrianopiresc',
#  'adrianotomason',
#  'adriel',
#  'adu',
#  'adult',
#  'adulter',
#  'advanc',
#  'advers',
#  'adversár',
#  'advert',
#  'advocac',
#  'advocaciager',
#  'advog',
#  'adági',
#  'adã',
#  'aed',
#  'aegypt',
#  'aeromó',
#  'aeron',
#  'aeronav',
#  'aeronáu',
#  'aeronáuticaeea',
#  'aeroport',
#  'aeroportu',
#  'aeroportuár',
#  'aerovi',
#  'aeródr',
#  'af',
#  'afag',
#  'afast',
#  'afeit',
#  'afenicolin',
#  'aferr',
#  'afet',
#  'afili',
#  'afim',
#  'afin',
#  'afinal',
#  'afirm',
#  'afirmars',
#  'afix',
#  'aflig',
#  'aflit',
#  'aflor',
#  'afog',
#  'afons',
#  'afonsob',
#  'afor',
#  'afranioboppr',
#  'afric',
#  'afrobrasil',
#  'afrodescend',
#  'afront',
#  'afroux',
#  'aft',
#  'afu',
#  'afugent',
#  'afund',
#  'afã',
#  'ag',
#  'again',
#  'against',
#  'agarr',
#  'agasalh',
#  'age',
#  'agenciabrasil',
#  'agenciafapesp',
#  'agenciapubl',
#  'agend',
#  'agent',
#  'aggression',
#  'agid',
#  'agil',
#  'agiliz',
#  'agim',
#  'agind',
#  'agir',
#  'agirm',
#  'agiss',
#  'agit',
#  'agiu',
#  'aglom',
#  'aglomer',
#  'aglomeraçãopropagand',
#  'ago',
#  'agoeaémanuel',
#  'agoniz',
#  'agor',
#  'agorac',
#  'agoraemanuel',
#  'agoranoticiasbr',
#  'agoraé',
#  'agoraéanossav',
#  'agoraéavezdasmulh',
#  'agoraéboul',
#  'agoraémanuel',
#  'agoraémanuerossett',
#  'agoraénossav',
#  'agost',
#  'agr',
#  'agraci',
#  'agrad',
#  'agradec',
#  'agradeç',
#  'agrand',
#  'agrav',
#  'agred',
#  'agreg',
#  'agres',
#  'agress',
#  'agressoresband',
#  'agrest',
#  'agricul',
#  'agricult',
#  'agrid',
#  'agroambient',
#  'agroecolog',
#  'agroecológ',
#  'agroindústr',
#  'agronegóci',
#  'agropecu',
#  'agropecuár',
#  'agrosp',
#  'agrotóx',
#  'agrár',
#  'agrícol',
#  'agu',
#  'aguanaoemercad',
#  'aguard',
#  'agud',
#  'aguent',
#  'aguerr',
#  'agui',
#  'aguilh',
#  'agulh',
#  'agustin',
#  'agênc',
#  'agênciabarc',
#  'agênciasbarc',
#  'ah',
#  'ahlisbo',
#  'ahmed',
#  'ahorapod',
#  'ai',
#  'aia',
#  'ailton',
#  'ailtonbenedit',
#  'aind',
#  'air',
#  'airlin',
#  'airport',
#  'aja',
#  'ajorgemed',
#  'ajud',
#  'ajudál',
#  'ajuiz',
#  'ajust',
#  'ajvalc',
#  'akopian',
#  'akshardh',
#  'al',
#  'ala',
#  'alag',
#  'alago',
#  'alambar',
#  'alambr',
#  'alan',
#  'alanapassosrj',
#  'alanf_barr',
#  'alarcon',
#  'alarg',
#  'alarm',
#  'alastr',
#  'alavanc',
#  'alberg',
#  'albert',
#  'albertocumpl',
#  'albertolk',
#  'albin',
#  'albuquerquedavy',
#  'alc',
#  'alcald',
#  'alcanc',
#  'alcanç',
#  'alceu_valenc',
#  'alcid',
#  'alckmin',
#  'alcolumbr',
#  'alcoól',
#  'alcânt',
#  'ald',
#  'aldac',
#  'alde',
#  'ale',
#  'ale_botelh',
#  'aleatóri',
#  'aleestefan',
#  'aleg',
#  'alegr',
#  'alegre',
#  'alegreagoraémanuel',
#  'alegrel',
#  'alegreum',
#  'alegrál',
#  'alegrí',
#  'aleit',
#  'alejandr',
#  'alejandrodott',
#  'aleksandr',
#  'alem',
#  'alemanh',
#  'alenc',
#  'alencastr',
#  'alent',
#  'alerj',
#  'alert',
#  'alesp',
#  'alessan',
#  'alessand',
#  'alessandr',
#  'alessandroloi',
#  'alessandromolon',
#  'alessi',
#  'alevidalx',
#  'alex',
#  'alexand',
#  'alexandr',
#  'alexandregarc',
#  'alexandreziben',
#  'alexcat',
#  'alexy',
#  'alfabe',
#  'alfandeg',
#  'alfarfall',
#  'alferd',
#  'alfred',
#  'alfredosirkil',
#  'alg',
#  'algem',
#  'algoritm',
#  'algoz',
#  'algum',
#  'algumac',
#  'alguém',
#  'alhe',
#  'alhei',
#  'alhulaiab',
#  'ali',
#  'alianç',
#  'aliançapelobrasil',
#  'alic',
#  'alice_portug',
#  'alicerc',
#  'alien',
#  'aliment',
#  'alimentacaosauda',
#  'alimentíc',
#  'alimond',
#  'alin',
#  'alinemidlej',
#  'alinh',
#  'alinn',
#  'alivi',
#  'aliás',
#  'alkmin',
#  'alkorap',
#  'all',
#  'allan',
#  'allanldsant',
#  'allantercalivr',
#  'allef_borg',
#  'allend',
#  'alm',
#  'alme',
#  'almir',
#  'almoc',
#  'almoç',
#  'aloc',
#  'aloch',
#  'aloj',
#  'along',
#  'alopr',
#  'alp',
#  'alphonsovm',
#  'alqu',
#  'alrasheed',
#  'als',
#  'alsuwaid',
#  'alt',
#  'altam',
#  'alter',
#  'altern',
#  'altin',
#  'altiv',
#  'altman',
#  'altruísm',
#  'altur',
#  'alug',
#  'aluguel',
#  'alumíni',
#  'alun',
#  'alunom',
#  'alus',
#  'alv',
#  'alvar',
#  'alvim',
#  'alvin',
#  'alvinegr',
#  'alvor',
#  'alwaslsc',
#  'alzheim',
#  'alç',
#  'além',
#  'alê',
#  'alíquot',
#  'alívi',
#  'alô',
#  'am',
#  'ama',
#  'amad',
#  'amadurec',
#  'amaldiço',
#  'amament',
#  'aman',
#  'amanc',
#  'amand',
#  'amandkl',
#  'amandystein',
#  'amanhec',
#  'amanhã',
#  'amanim',
#  'amanpour',
#  'amap',
#  'amapa',
#  'amapapedesocorr',
#  'amapárestabelec',
#  'amar',
#  'amarantern',
#  'amarel',
#  'amarg',
#  'amarrando',
#  'amaur',
#  'amazing',
#  'amazon',
#  'amazonasp',
#  'amazoniaazulbr',
#  'amazôn',
#  'amb',
#  'ambas',
#  'ambi',
#  'ambici',
#  'ambicion',
#  'ambient',
#  'ambivalet',
#  'ambos',
#  'ambul',
#  'ambulanteleg',
#  'ambulatóri',
#  'ambulânc',
#  'ambígu',
#  'ame',
#  'ameac',
#  'amealh',
#  'ameaç',
#  'amei',
#  'amen',
#  'amendoncaagu',
#  'amendoncamjsp',
#  'ameniz',
#  'amer',
#  'americ',
#  'american',
#  'americanasbrasil',
#  'americanópolil',
#  'amig',
#  'amin',
#  'amir',
#  'amit',
#  'amizad',
#  'amo',
#  'amon',
#  'among',
#  'amongboul',
#  'amongboulu',
#  'amooo',
#  'amor',
#  'amorim',
#  'amorin',
#  'amosp',
#  'amostr',
#  'amotin',
#  'amou',
#  'amp',
#  'ampar',
#  'ampl',
#  'ampli',
#  'amplific',
#  'amplitud',
#  'amál',
#  'amél',
#  'amém',
#  'amér',
#  'an',
#  'ana',
#  'anacmielk',
#  'anadut',
#  'anal',
#  'analfabet',
#  'analgés',
#  'analis',
#  'analy',
#  'anan',
#  'ananindeu',
#  'anapaul',
#  'anapaulavol',
#  'anapu',
#  'anarcofin',
#  'anavitór',
#  'anc',
#  'ancestr',
#  'anchiet',
#  'ancin',
#  'ancor',
#  'and',
#  'andaraí',
#  'anderson',
#  'andersondaleci',
#  'andes_pedr',
#  'andrad',
#  'andradin',
#  'andrdin',
#  'andre',
#  'andreabocell',
#  'andreaf',
#  'andrefernm',
#  'andrefran',
#  'andreiadejesuu',
#  'andrepetr',
#  'andress',
#  'android',
#  'andré',
#  'aneel',
#  'aneel_govbr',
#  'anel',
#  'anencefal',
#  'anestes',
#  'anestesi',
#  'anex',
#  'angel',
#  'angela_albin',
#  'angela_gandr',
#  'angelpelobrasil',
#  'angol',
#  'angr',
#  'angu',
#  'angusti',
#  'angúst',
#  'anhagabaú',
#  'anhangabaú',
#  'anhemb',
#  'anholet',
#  'aniell',
#  'anielle_franc',
#  'aniellefranc',
#  'anil',
#  'anim',
#  'animal',
#  'animaldecret',
#  'aninh',
#  'aniquil',
#  'anist',
#  'anisti',
#  'anit',
#  'anitt',
#  'aniversári',
#  'anj',
#  'anjunhun',
#  'anm',
#  'ann',
#  'anna_cavazzin',
#  'annakarinapsol',
#  'anne_hidalg',
#  'anniversary',
#  'ano',
#  'anonim',
#  'anonov',
#  'anoparticip',
#  'anormal',
#  'anossemdorothy',
#  'anot',
#  'anoth',
#  'anse',
#  'ansei',
#  'ansi',
#  'ant',
#  'antagon',
#  'antagôn',
#  'anteced',
#  'antecip',
#  'anteont',
#  'anter',
#  'anteri',
#  'anterogrec',
#  'antiabort',
#  'antiambient',
#  'antibolsonar',
#  'antibrasil',
#  'anticientíf',
#  'anticorrupç',
#  'anticrim',
#  'antidemocrá',
#  'antidrog',
#  'antidumping',
#  'antieconôm',
#  'antif',
#  'antifasc',
#  'antifaspelademocrac',
#  'antifraud',
#  'antig',
#  'antihuman',
#  'antiindígen',
#  'antimanicom',
#  'antiministr',
#  'antipet',
#  'antipolí',
#  'antipopul',
#  'antirac',
#  'antirepublic',
#  'antirrac',
#  'antirrasc',
#  'antirrepublic',
#  'antirretrovir',
#  'antisemit',
#  'antision',
#  'antissemit',
#  'antissequestr',
#  'antivacin',
#  'antivir',
#  'antié',
#  'anton',
#  'antoni',
#  'antoniet',
#  'antonin',
#  'antoniofsnetosp',
#  'antr',
#  'antropólog',
#  'antun',
#  'antárt',
#  'antídot',
#  'antígu',
#  'antôni',
#  'anual',
#  'anul',
#  'anulastf',
#  'anunc',
#  'anunci',
#  'anvis',
#  'anvisa_ofic',
#  'anális',
#  'análog',
#  'anápolisg',
#  'anôn',
#  'anúnci',
#  'aond',
#  'aoviv',
#  'ap',
#  'apa',
#  'apadrinh',
#  'apag',
#  'apaixon',
#  'apanh',
#  'aparat',
#  'aparec',
#  'aparelh',
#  'aparent',
#  'apart',
#  'apartheid',
#  'apartidár',
#  'apatif',
#  'apatifamn',
#  'apavor',
#  'apcesaraugust',
#  'apeg',
#  'apegas',
#  'apel',
#  'apen',
#  'apeoesp',
#  'apequen',
#  'aperfeiço',
#  'apert',
#  'apertaev',
#  'apes',
#  'apetit',
#  'apezequiel',
#  'api',
#  'apib',
#  'apibofic',
#  'apicul',
#  'apicult',
#  'apit',
#  'aplaud',
#  'aplaus',
#  'aplic',
#  'apo',
#  'apocalip',
#  'apocalips',
#  'apoi',
#  'apoiobrequedosapp',
#  'apoiál',
#  'apolog',
#  'apont',
#  'aport',
#  'aposent',
#  'aposentad',
#  'apost',
#  'apoteos',
#  'app',
#  'apreci',
#  'apreend',
#  'apreens',
#  'apreensivaespec',
#  'aprend',
#  'aprendiz',
#  'apres',
#  'apresent',
#  'apress',
#  'apreç',
#  'aprim',
#  'aprimor',
#  'aprision',
#  'aprofund',
#  'apront',
#  'apropri',
#  'apropriad',
#  'aprov',
#  'aprovadofundebpraval',
#  'aprovaemergenciacult',
#  'aprovafundeb',
#  'aprovafundebintegr',
#  'aprovasenadopl',
#  'aprove',
#  'aproveit',
#  'aproveitars',
#  'aprovál',
#  'aprox',
#  'aproxim',
#  'aproximad',
#  'apsen',
#  'apur',
#  'apyterew',
#  'apó',
#  'apócrif',
#  'após',
#  'aqu',
#  'aquaviár',
#  'aquaviáriocabot',
#  'aquec',
#  'aquecêl',
#  'aquis',
#  'aquá',
#  'aquí',
#  'aquífer',
#  'ar',
#  'ara',
#  'aracaju',
#  'aracajus',
#  'aracajú',
#  'aracat',
#  'aragua',
#  'aram',
#  'arand',
#  'arapong',
#  'arapu',
#  'arapuan',
#  'arar',
#  'araraqu',
#  'ararasazuil',
#  'ararib',
#  'aratub',
#  'araut',
#  'arax',
#  'araçariguam',
#  'araçatub',
#  'araçuaí',
#  'araçuaímg',
#  'araúj',
#  'arbitr',
#  'arbitrariedad',
#  'arbitrár',
#  'arbor',
#  'arbítri',
#  'arc',
#  'arcanj',
#  'arcebisp',
#  'arcondicion',
#  'ard',
#  'ardern',
#  'ardil',
#  'ardu',
#  'are',
#  'aren',
#  'argent',
#  'argentin',
#  'argument',
#  'ari',
#  'arian',
#  'aricanduv',
#  'arid',
#  'ariovald',
#  'arit',
#  'aritmé',
#  'arm',
#  'armadilh',
#  'arman',
#  'armazen',
#  'armazém',
#  'armên',
#  'armêni',
#  'arnald',
#  'arnsflavi',
#  'aroeiracartum',
#  'arold',
#  'aroldeoliv',
#  'arom',
#  'around',
#  'arqmrf',
#  'arqu',
#  'arquipélag',
#  'arquitet',
#  'arquiv',
#  'arra',
#  'arraig',
#  'arranc',
#  'arranj',
#  'arras',
#  'arrast',
#  'arrecad',
#  'arrecadatór',
#  'arrefec',
#  'arregaç',
#  'arremat',
#  'arremet',
#  'arrend',
#  'arrep',
#  'arrepend',
#  'arrepi',
#  'arret',
#  'arrisc',
#  'arrisqu',
#  'arritm',
#  'arrog',
#  'arroi',
#  'arroj',
#  'arromb',
#  'arroub',
#  'arroz',
#  'arrud',
#  'arrum',
#  'arsen',
#  'art',
#  'artax',
#  'artedeensin',
#  'artes',
#  'artesan',
#  'artesi',
#  'artesp',
#  'artesã',
#  'arthur',
#  'arthurmoledov',
#  'arthurweint',
#  'articul',
#  ...]

# %%
teste = pd.DataFrame(matrix,columns=cv.get_feature_names())

# %%
X = teste
y = tweets_treino['name']

# %% [markdown]
# ## Treinando Modelo de Regressão Logística

# %%
model = lr(solver='lbfgs', max_iter=1000)
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#testando modelo
model.predict(X)
# Out:
# array(['Guilherme Boulos', 'Bruno Covas', 'Bruno Covas', ...,
#        'Marina Silva', 'Marina Silva', 'Marina Silva'], dtype=object)

# %%
model.classes_
# Out:
# array(['Bruno Covas', 'Celso Russomanno', 'Damares Alves',
#        'Dilma Rousseff', 'Guilherme Boulos', 'Jair M. Bolsonaro',
#        'João Doria', 'Lula', 'Manuela', 'Marcelo Crivella',
#        'Marina Silva'], dtype=object)

# %%
x = input('Digite uma frase: ')
digite(x)
# Out:
# Digite uma frase: Lula livre!
#       Figura_Politica  Probabilidade
# 0         Bruno Covas       0.000847
# 1    Celso Russomanno       0.002657
# 2       Damares Alves       0.008030
# 3      Dilma Rousseff       0.034930
# 4    Guilherme Boulos       0.012865
# 5   Jair M. Bolsonaro       0.052275
# 6          João Doria       0.004853
# 7                Lula       0.835610
# 8             Manuela       0.035002
# 9    Marcelo Crivella       0.002439
# 10       Marina Silva       0.010493
